# %% [markdown]
# <a href="https://colab.research.google.com/github/VelocidadeTV/VelocidadeTV/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from matplotlib import pyplot as plt


x = [15,200,30,60,25]
y = [2,15,6,60,41]
plt.plot (x,y)
plt.title('info')
plt.ylabel ('Y axis')
plt.xlabel ('x axis')
plt.show()
